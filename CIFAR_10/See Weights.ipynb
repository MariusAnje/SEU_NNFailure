# %%
import torch

# %%
a = torch.load('nin.best.pth.tar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-527ed85b870b> in <module>()
#       1 a = torch.load('nin.best.pth.tar')
# ----> 2 for items in a['state_dictt']:
#       3     print(items.max())
#
# KeyError: 'state_dictt'

# %%
for items in a['state_dict']:
    if items.find('.weight') != -1 and items.find('bn') == -1:
        print (items, a['state_dict'][items])
# Out:
# ('xnor.0.weight', tensor([[[[-1.9401e-01, -1.3506e-01,  7.2237e-03,  9.3163e-02, -4.8037e-02],
#           [ 5.4613e-02,  3.2667e-03,  1.8339e-02, -9.3577e-02, -1.5723e-01],
#           [-3.5334e-02,  6.5301e-02, -1.8231e-01, -2.7251e-01, -1.3898e-01],
#           [-2.0839e-01, -2.0256e-01, -2.5351e-01, -1.1335e-02, -1.9998e-01],
#           [-2.5230e-01, -2.2936e-01, -6.4397e-02, -4.3621e-02, -1.0513e-01]],
#
#          [[ 2.7433e-02, -5.5659e-02, -3.7087e-01, -2.2016e-01,  1.4887e-01],
#           [ 2.5922e-02, -2.1262e-01, -3.7483e-01, -4.6586e-01, -1.6639e-01],
#           [-1.8676e-01, -3.2684e-01, -4.1303e-01, -3.0767e-01,  1.2768e-01],
#           [-1.4300e-01, -4.7700e-01, -4.1324e-01, -4.6578e-02,  7.3762e-02],
#           [-5.0317e-01, -5.3234e-01, -4.2922e-01, -2.7917e-01, -2.7918e-02]],
#
#          [[ 1.4351e-01,  2.0213e-02, -9.7868e-02,  7.7320e-02, -2.1107e-02],
#           [-1.0346e-02, -1.2338e-01, -3.0111e-02, -5.3016e-02, -2.2687e-01],
# ...
